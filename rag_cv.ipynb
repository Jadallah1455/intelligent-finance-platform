# %%
##Old Version

# %%
# imports
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr
from google.colab import userdata

client = OpenAI(
    api_key= userdata.get('OPENAI_API_KEY')
)

model_name = "gpt-4o-mini"

reader = PdfReader(r"/Leena Almoradi CV 2025 (6).pdf")
cv = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        cv += text

name = "leena almoradi"

system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a cv of {name}'s background use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website."

system_prompt += f"\n\n## CV:\n{cv}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(model=model_name, messages=messages)

    return response.choices[0].message.content

gr.ChatInterface(chat, type="messages").launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://c5cfd4b6ebfefaa38f.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c5cfd4b6ebfefaa38f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
## Fixed Chunking

# %%
# =============================
# Imports
# =============================
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr
import faiss
import numpy as np
from google.colab import userdata
from langchain.text_splitter import RecursiveCharacterTextSplitter

# =============================
# Init
# =============================
client = OpenAI(api_key=userdata.get("OPENAI_API_KEY"))
chat_model = "gpt-4o-mini"
embedding_model = "text-embedding-3-small"

# =============================
# Step 1: Load CV
# =============================
reader = PdfReader(r"/content/Karim Nabil PM Resume - August 2025.pdf")
cv_text = "".join(page.extract_text() or "" for page in reader.pages)

# =============================
# Step 2: Chunking (LangChain)
# =============================
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    length_function=len,
    separators=["\n\n", "\n", ".", " ", ""]
)
chunks = text_splitter.split_text(cv_text)

# =============================
# Step 3: Embeddings + FAISS
# =============================
# Create embeddings for all chunks
embeddings = [
    client.embeddings.create(model=embedding_model, input=chunk).data[0].embedding
    for chunk in chunks
]

embeddings = np.array(embeddings).astype("float32")

# build FAISS index
index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)

# keep chunks aligned by index
chunk_list = chunks

# =============================
# Step 4: Retrieval
# =============================
def retrieve(query, top_k=3):
    query_emb = client.embeddings.create(model=embedding_model, input=query).data[0].embedding
    query_emb = np.array([query_emb], dtype="float32")
    D, I = index.search(query_emb, top_k)
    return [chunk_list[i] for i in I[0]]

# =============================
# Step 5: Chat
# =============================
def chat(message, history):
    context_chunks = retrieve(message, top_k=3)
    context = "\n\n".join(context_chunks)

    system_prompt = f"""You are acting as Karim Nabil.
Answer questions faithfully using the following retrieved context from Karim’s CV:

{context}

Always stay professional and engaging, as if speaking to a potential client or employer.
If something is not in the CV, politely say you don’t have that info.
"""

    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(model=chat_model, messages=messages)
    return response.choices[0].message.content

# =============================
# Gradio UI
# =============================
gr.ChatInterface(chat, type="messages").launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://f4d6420dcce30e0f50.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f4d6420dcce30e0f50.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 44.8 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
## Fixed Chunking

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1443775441.py in <cell line: 0>()
#       1 # imports
#       2 from openai import OpenAI
# ----> 3 from pypdf import PdfReader
#       4 import gradio as gr
#       5 from google.colab import userdata
#
# ModuleNotFoundError: No module named 'pypdf'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)

# %%
## Context-Aware Chunking

# %%
import json
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr
import faiss
import numpy as np
from google.colab import userdata
from langchain.text_splitter import RecursiveCharacterTextSplitter

# =============================
# Init
# =============================
client = OpenAI(api_key=userdata.get("OPENAI_API_KEY"))
chat_model = "gpt-4o-mini"
embedding_model = "text-embedding-3-small"

# =============================
# Step 1: Load CV
# =============================
reader = PdfReader(r"/content/Karim Nabil PM Resume - August 2025.pdf")
cv_text = "".join(page.extract_text() or "" for page in reader.pages)

def llm_chunk_cv(cv_text):
    messages = [
        {
            "role": "system",
            "content": (
                "Split the following CV into logical sections for example"
                "(Experience, Education, Summary). "
                "Return each section as a JSON array of objects with 'section' and 'content' ."
            )
        },
        {"role": "user", "content": cv_text}
    ]

    resp = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
        temperature=0
    )

    raw_output = resp.choices[0].message.content.strip()

    # Remove markdown code block fences if they exist
    if raw_output.startswith("```json"):
        raw_output = raw_output[7:]
    if raw_output.endswith("```"):
        raw_output = raw_output[:-3]

    parsed = json.loads(raw_output)
    return parsed

sections = llm_chunk_cv(cv_text)

# %%
print(json.dumps(sections, indent=2))
# Out:
# [
#   {
#     "section": "Summary",
#     "content": "Driven professional with a blend of engineering expertise, business development acumen, and product management skills. Demonstrated success in pioneering product initiatives, forging strategic partnerships, and leveraging data for user-centric solutions. Adept at translating market insights into actionable product strategies. Eager to apply my versatile background to lead and innovate in product management roles, delivering value and driving growth."
#   },
#   {
#     "section": "Experience",
#     "content": [
#       {
#         "title": "AI Product Manager/ Business Developer",
#         "company": "Stealth Mode",
#         "duration": "March 2025 \u2013 Ongoing",
#         "location": "Canada, Full-time, remote",
#         "industry": "Agentic AI OS SaaS",
#         "responsibilities": [
#           "Led the product discovery phase by engaging directly with target users to uncover pain points, validate core problems, and define solution fit.",
#           "Designed comprehensive user flows, personas, and user stories to guide MVP development with development and AI teams.",
#           "Built and launched the functional prototype using Vibe coding and no-code tools to rapidly test hypotheses.",
#           "Forged strategic partnerships that aim at reaching over 15,000 users within the initial launch period."
#         ]
#       },
#       {
#         "title": "Product Business Manager",
#         "company": "STEM Entrepreneurship Center",
#         "duration": "June 2025 \u2013 Ongoing",
#         "location": "Egypt, Part time, remote",
#         "industry": "E-learning",
#         "responsibilities": [
#           "Responsible for building their LMS product to monetize communities they built from events management.",
#           "Managed to craft a strategic plan to mix commercial teams intentions and product/tech team capabilities to launch the MVP fast.",
#           "Managing the quality team to produce needed courses by the end of the development stage."
#         ]
#       },
#       {
#         "title": "Head of Business Development/Product Developer",
#         "company": "Provin",
#         "duration": "October 2023 \u2013 March 2025",
#         "location": "USA, Full-time, Remote",
#         "industry": "Technical Recruitment",
#         "responsibilities": [
#           "Drove the full product lifecycle from discovery and problem articulation to solution design, execution with tech teams, and market launch.",
#           "Cultivated strategic partnerships by initiating discovery calls and validating hypotheses with potential clients, leading to successful engagements with product experts from Google, Apple, Microsoft, Visa, IDEO, and Boeing.",
#           "Led marketing and sales initiatives for product launch, employing targeted strategies that maximized market penetration and customer engagement which successfully led to break-even in six months.",
#           "Created Provin AI Agent from scratch to help our clients find needed talents faster than ever."
#         ]
#       },
#       {
#         "title": "Product Manager",
#         "company": "EduGraphic",
#         "duration": "November 2023 \u2013 October 2024",
#         "location": "Part-time, Remote",
#         "industry": "Education",
#         "responsibilities": [
#           "Analyzed market trends and identified growth opportunities, significantly increasing our YouTube Channel\u2019s views to over 1,000,000 views.",
#           "Implemented data-driven strategies to make user-centric decisions, improving content relevance and viewer engagement."
#         ]
#       },
#       {
#         "title": "Teaching Assistant",
#         "company": "Engineering Faculty, Zagazig University",
#         "duration": "June 2022 \u2013 September 2024",
#         "location": "Part-time",
#         "responsibilities": [
#           "Educated engineering students in Engineering Drawing, Mechanical Control, and Theory of Machine, incorporating industry integration strategies to bolster hands-on experience.",
#           "Promoted practical learning by developing strategies that bridge the gap between theoretical knowledge and industry practice, preparing students for real-world challenges."
#         ]
#       },
#       {
#         "title": "Business Development | Product Development Engineer",
#         "company": "Sahara Complete Services for Petroleum Services",
#         "duration": "October 2021 \u2013 September 2024",
#         "location": "Part-time",
#         "industry": "Oil and Gas",
#         "responsibilities": [
#           "Strategized business growth for 5 subsidiaries, enhancing their market presence in diverse sectors including Industry Services and Advanced Technology.",
#           "Facilitated international partnerships for technological advancements, resulting in the development of two pioneering products: a Distributed Temperature Sensing (DTS) system for gas wells monitoring and a Drone Lead Detection system for remote pipeline gas leakage detection."
#         ]
#       }
#     ]
#   },
#   {
#     "section": "Extracurricular Activities",
#     "content": [
#       {
#         "title": "Team Leader",
#         "organization": "Ministry of Youth and Sports of Egypt",
#         "duration": "May 2021",
#         "responsibilities": [
#           "I was an entrepreneurship team leader in the Egyptian delegation representing Egypt in the 1st Egyptian and Russian Youth Forum in Moscow and Kazan.",
#           "Leading a team of 5 members to prepare and present an overview on the entrepreneurship ecosystem in Egypt."
#         ]
#       },
#       {
#         "title": "Chairman and Co-founder",
#         "organization": "ZEClub (Zagazig Entrepreneurship Club)",
#         "duration": "June 2020 \u2013 December 2020",
#         "responsibilities": [
#           "Managing a team of 6 board members and 100+ members.",
#           "Establishing a booming digital existence that reached +600,000 impressions on social."
#         ]
#       }
#     ]
#   },
#   {
#     "section": "Education",
#     "content": [
#       {
#         "degree": "BCs in Mechanical Design and Production Engineering",
#         "institution": "Zagazig University",
#         "year": 2021,
#         "details": "92%, Excellent with Honor, 1st of department."
#       },
#       {
#         "degree": "Marketing nanodegree",
#         "institution": "Udacity"
#       },
#       {
#         "degree": "Google career certificate",
#         "field": "Automation using Python"
#       }
#     ]
#   },
#   {
#     "section": "Courses and Certifications",
#     "content": [
#       "Agentic AI Engineering course by Ed Donner.",
#       "Master AI, LLM and Agents by Ed Donner.",
#       "MixPanel Product Analytics from Product School.",
#       "Projects Management: The Basics for Success on Coursera.",
#       "Growth Strategies from Wharton Business School on Coursera.",
#       "Mckinsey & Company Forward Program Participant 2022.",
#       "Algorithms and data structures from Princeton University on Coursera."
#     ]
#   },
#   {
#     "section": "Skill Highlights",
#     "content": [
#       "Project Management & Planning: Professional in managing projects and planning effectively.",
#       "Microsoft Office: Proficient in all Microsoft Office tools.",
#       "Data Analysis: Using suitable tools to provide insights and reports.",
#       "Communication: I worked as a sales & business developer. I have been a team leader for several times and a volunteer in several places.",
#       "Negotiation: Proven ability to make successful +$100K deals.",
#       "Adaptability: able to adjust in rapidly changing environment and to prioritize my activities and set the right expectations with my internal and external stakeholders.",
#       "Presentation: I delivered +80 presentations in several deals, competitions, and events in Egypt and internationally.",
#       "Problem Solving: I adore solving technical problems as I participated in a lot of competitive programming competitions which put you under the pressure of solving problems in certain time at a certain level of complexity and optimization."
#     ]
#   },
#   {
#     "section": "Languages",
#     "content": [
#       "Arabic \u2013 Native",
#       "English - Fluent in both Spoken & Written English."
#     ]
#   },
#   {
#     "section": "Initiatives and Accomplishments",
#     "content": [
#       "Agentic AI Engineering instructor.",
#       "n8n with Karim YouTube course.",
#       "NASA Space Apps Cairo winner and global nominee twice.",
#       "2nd place in YLP (Youth Leadership Program) With UNDP.",
#       "African youth forum for entrepreneur\u2019s winner.",
#       "The Ideal Student @ Zagazig university 2020."
#     ]
#   }
# ]

# %%
embeddings = []
section_texts = []
metadata = []

for s in sections:
    section_name = s["section"]
    content = s["content"]

    if not content:
        continue

    emb = client.embeddings.create(
        model=embedding_model,
        input=json.dumps(content, indent=2)
    ).data[0].embedding

    embeddings.append(emb)
    section_texts.append(content)
    metadata.append(section_name)

# Convert to numpy for FAISS
embeddings = np.array(embeddings, dtype="float32")
print(metadata, embeddings, section_texts)
# Out:
# ['Summary', 'Experience', 'Extracurricular Activities', 'Education', 'Courses and Certifications', 'Skill Highlights', 'Languages', 'Initiatives and Accomplishments'] [[ 8.89946613e-03 -9.45531297e-03  1.71721261e-02 ...  8.44118826e-04
#    3.25702727e-02 -9.28382855e-03]
#  [-2.84280125e-02 -2.81259650e-03  3.96570787e-02 ... -6.21862803e-03
#   -7.73952669e-03  4.12561558e-03]
#  [-4.71006474e-03 -8.84763524e-03  8.09948985e-03 ... -1.03048924e-02
#   -1.16710719e-02 -5.97540662e-03]
#  ...
#  [-1.61280092e-02 -2.36737952e-02  6.13268837e-02 ... -1.82135291e-02
#   -3.78444602e-05  1.85800735e-02]
#  [-1.49572631e-02 -3.10543017e-03  7.57737160e-02 ... -3.92277688e-02
#   -1.75781362e-02  5.06803766e-03]
#  [-5.97637845e-03 -3.85707058e-02  1.50536755e-02 ... -3.84597108e-02
#   -1.93265427e-04 -1.65382307e-02]] ['Driven professional with a blend of engineering expertise, business development acumen, and product management skills. Demonstrated success in pioneering product initiatives, forging strategic partnerships, and leveraging data for user-centric solutions. Adept at translating market insights into actionable product strategies. Eager to apply my versatile background to lead and innovate in product management roles, delivering value and driving growth.', [{'title': 'AI Product Manager/ Business Developer', 'company': 'Stealth Mode', 'duration': 'March 2025 – Ongoing', 'location': 'Canada, Full-time, remote', 'industry': 'Agentic AI OS SaaS', 'responsibilities': ['Led the product discovery phase by engaging directly with target users to uncover pain points, validate core problems, and define solution fit.', 'Designed comprehensive user flows, personas, and user stories to guide MVP development with development and AI teams.', 'Built and launched the functional prototype using Vibe coding and no-code tools to rapidly test hypotheses.', 'Forged strategic partnerships that aim at reaching over 15,000 users within the initial launch period.']}, {'title': 'Product Business Manager', 'company': 'STEM Entrepreneurship Center', 'duration': 'June 2025 – Ongoing', 'location': 'Egypt, Part time, remote', 'industry': 'E-learning', 'responsibilities': ['Responsible for building their LMS product to monetize communities they built from events management.', 'Managed to craft a strategic plan to mix commercial teams intentions and product/tech team capabilities to launch the MVP fast.', 'Managing the quality team to produce needed courses by the end of the development stage.']}, {'title': 'Head of Business Development/Product Developer', 'company': 'Provin', 'duration': 'October 2023 – March 2025', 'location': 'USA, Full-time, Remote', 'industry': 'Technical Recruitment', 'responsibilities': ['Drove the full product lifecycle from discovery and problem articulation to solution design, execution with tech teams, and market launch.', 'Cultivated strategic partnerships by initiating discovery calls and validating hypotheses with potential clients, leading to successful engagements with product experts from Google, Apple, Microsoft, Visa, IDEO, and Boeing.', 'Led marketing and sales initiatives for product launch, employing targeted strategies that maximized market penetration and customer engagement which successfully led to break-even in six months.', 'Created Provin AI Agent from scratch to help our clients find needed talents faster than ever.']}, {'title': 'Product Manager', 'company': 'EduGraphic', 'duration': 'November 2023 – October 2024', 'location': 'Part-time, Remote', 'industry': 'Education', 'responsibilities': ['Analyzed market trends and identified growth opportunities, significantly increasing our YouTube Channel’s views to over 1,000,000 views.', 'Implemented data-driven strategies to make user-centric decisions, improving content relevance and viewer engagement.']}, {'title': 'Teaching Assistant', 'company': 'Engineering Faculty, Zagazig University', 'duration': 'June 2022 – September 2024', 'location': 'Part-time', 'responsibilities': ['Educated engineering students in Engineering Drawing, Mechanical Control, and Theory of Machine, incorporating industry integration strategies to bolster hands-on experience.', 'Promoted practical learning by developing strategies that bridge the gap between theoretical knowledge and industry practice, preparing students for real-world challenges.']}, {'title': 'Business Development | Product Development Engineer', 'company': 'Sahara Complete Services for Petroleum Services', 'duration': 'October 2021 – September 2024', 'location': 'Part-time', 'industry': 'Oil and Gas', 'responsibilities': ['Strategized business growth for 5 subsidiaries, enhancing their market presence in diverse sectors including Industry Services and Advanced Technology.', 'Facilitated inter ...

# %%
index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)

# %%
def retrieve(query, top_k=2):
    query_emb = client.embeddings.create(
        model=embedding_model,
        input=query
    ).data[0].embedding
    query_emb = np.array([query_emb], dtype="float32")

    D, I = index.search(query_emb, top_k)

    results = []
    for idx in I[0]:
        results.append({
            "section": metadata[idx],
            "content": section_texts[idx]
        })
    return results

# %%
results = retrieve("what is your Education?")
for r in results:
    print(f"== {r['section']} ==")
    print(r["content"][:200], "...\n")
# Out:
# == Education ==
# [{'degree': 'BCs in Mechanical Design and Production Engineering', 'institution': 'Zagazig University', 'year': 2021, 'details': '92%, Excellent with Honor, 1st of department.'}, {'degree': 'Marketing nanodegree', 'institution': 'Udacity'}, {'degree': 'Google career certificate', 'field': 'Automation using Python'}] ...
#
# == Initiatives and Accomplishments ==
# ['Agentic AI Engineering instructor.', 'n8n with Karim YouTube course.', 'NASA Space Apps Cairo winner and global nominee twice.', '2nd place in YLP (Youth Leadership Program) With UNDP.', 'African youth forum for entrepreneur’s winner.', 'The Ideal Student @ Zagazig university 2020.'] ...

# %%
def chat(message, history):
    context_chunks = retrieve(message, top_k=3)
    context = "\n\n".join([f"### {c['section']}\n{c['content']}" for c in context_chunks])

    system_prompt = f"""You are acting as Karim Nabil.
Answer questions faithfully using the following retrieved context from Karim’s CV:

{context}

Always stay professional and engaging, as if speaking to a potential client or employer.
If something is not in the CV, politely say you don’t have that info.
"""

    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(model=chat_model, messages=messages)
    return response.choices[0].message.content


# =============================
# Gradio UI
# =============================
gr.ChatInterface(chat, type="messages").launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://910edd34c80a9bd65d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://910edd34c80a9bd65d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
